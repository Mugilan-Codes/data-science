# %%
import pandas as pd

# %%
amazon_json = pd.read_json('amazon.json')

# %%
amazon_json
# Out:
#                                                  title discountedPrice  \
# 0    Lenovo IdeaPad S540 10th Gen Intel Core i5 15....          60,990
# 1    Dell Vostro 3401 14" FHD Anti Glare Display La...          38,790
# 2    Lenovo Ideapad Slim 3i 10th Gen Intel Core i3 ...          36,990
# 3    Acer Acer One Intel Pentium Gold 4415U Process...          27,500
# 4    Dell Inspiron 3505 15.6" FHD Display Laptop (R...          34,898
# ..                                                 ...             ...
# 343  Lenovo Legion Y540 Intel Core i5 9th Gen 15.6 ...          62,990
# 344  (Renewed) Dell Lattitude E5270 -12.5 inch HD L...          37,999
# 345                                               None            None
# 346                                               None            None
# 347                                               None            None
#
#                                                 imgUrl actualPrice  \
# ...

# %%
amazon_csv = amazon_json.to_csv('amazon.csv')

# %%
df = pd.read_csv('amazon.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Lenovo IdeaPad S540 10th Gen Intel Core i5 15....
# 1           1  Dell Vostro 3401 14" FHD Anti Glare Display La...
# 2           2  Lenovo Ideapad Slim 3i 10th Gen Intel Core i3 ...
# 3           3  Acer Acer One Intel Pentium Gold 4415U Process...
# 4           4  Dell Inspiron 3505 15.6" FHD Display Laptop (R...
#
#   discountedPrice                                             imgUrl  \
# 0          60,990  https://m.media-amazon.com/images/I/911dhIY2SC...
# 1          38,790  https://m.media-amazon.com/images/I/51CEknIIHc...
# 2          36,990  https://m.media-amazon.com/images/I/61s7sJEpsV...
# 3          27,500  https://m.media-amazon.com/images/I/61S1y24Ggm...
# 4          34,898  https://m.media-amazon.com/images/I/51MKXqHKBQ...
#
#   actualPrice              rating
# 0     ₹60,990  4.5 out of 5 stars
# 1     ₹38,790  3.7 out of 5 stars
# 2     ₹36,990  4.0 out of 5 stars
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       348 non-null    int64
#  1   title            290 non-null    object
#  2   discountedPrice  273 non-null    object
#  3   imgUrl           290 non-null    object
#  4   actualPrice      273 non-null    object
#  5   rating           213 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 16.4+ KB

# %%
amazon_dropped_null = df.dropna()

# %%
amazon_dropped_null
# Out:
#      Unnamed: 0                                              title  \
# 0             0  Lenovo IdeaPad S540 10th Gen Intel Core i5 15....
# 1             1  Dell Vostro 3401 14" FHD Anti Glare Display La...
# 2             2  Lenovo Ideapad Slim 3i 10th Gen Intel Core i3 ...
# 3             3  Acer Acer One Intel Pentium Gold 4415U Process...
# 5             5  Dell Vostro 3405 14" HD AG Display Laptop (AMD...
# ..          ...                                                ...
# 335         335  Lenovo Ideapad Slim 3 AMD Ryzen 3 15.6 Inch Fh...
# 336         336  Lenovo IdeaPad Flex 5 10th Gen Intel Core i3 1...
# 338         338  ASUS VivoBook S14 Intel Core i5-1035G1 10th Ge...
# 343         343  Lenovo Legion Y540 Intel Core i5 9th Gen 15.6 ...
# 344         344  (Renewed) Dell Lattitude E5270 -12.5 inch HD L...
#
#     discountedPrice                                             imgUrl  \
# 0            60,990  https://m.media-amazon.com/images/I/911dhIY2SC...
# ...

# %%
amazon_cleaned = amazon_dropped_null.drop(columns=['Unnamed: 0'])

# %%
amazon_cleaned
# Out:
#                                                  title discountedPrice  \
# 0    Lenovo IdeaPad S540 10th Gen Intel Core i5 15....          60,990
# 1    Dell Vostro 3401 14" FHD Anti Glare Display La...          38,790
# 2    Lenovo Ideapad Slim 3i 10th Gen Intel Core i3 ...          36,990
# 3    Acer Acer One Intel Pentium Gold 4415U Process...          27,500
# 5    Dell Vostro 3405 14" HD AG Display Laptop (AMD...          28,990
# ..                                                 ...             ...
# 335  Lenovo Ideapad Slim 3 AMD Ryzen 3 15.6 Inch Fh...          31,089
# 336  Lenovo IdeaPad Flex 5 10th Gen Intel Core i3 1...          43,990
# 338  ASUS VivoBook S14 Intel Core i5-1035G1 10th Ge...          57,990
# 343  Lenovo Legion Y540 Intel Core i5 9th Gen 15.6 ...          62,990
# 344  (Renewed) Dell Lattitude E5270 -12.5 inch HD L...          37,999
#
#                                                 imgUrl actualPrice  \
# ...

# %%
amazon_cleaned.to_csv('amazon_cleaned.csv')
